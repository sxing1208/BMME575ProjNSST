# %%
import os
import requests

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case29/mr1/{numstr}.gif"

for i in range(5,24):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './alz/mri'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)
# Out:
# Downloaded ./alz/mri\1.gif
# Downloaded ./alz/mri\2.gif
# Downloaded ./alz/mri\3.gif
# Downloaded ./alz/mri\4.gif
# Downloaded ./alz/mri\5.gif
# Downloaded ./alz/mri\6.gif
# Downloaded ./alz/mri\7.gif
# Downloaded ./alz/mri\8.gif
# Downloaded ./alz/mri\9.gif
# Downloaded ./alz/mri\10.gif
# Downloaded ./alz/mri\11.gif
# Downloaded ./alz/mri\12.gif
# Downloaded ./alz/mri\13.gif
# Downloaded ./alz/mri\14.gif
# Downloaded ./alz/mri\15.gif
# Downloaded ./alz/mri\16.gif
# Downloaded ./alz/mri\17.gif
# Downloaded ./alz/mri\18.gif
# Downloaded ./alz/mri\19.gif

# %%
import os
import requests

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case29/tc1/{numstr}.gif"

for i in range(5,24):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './alz/pet'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)
# Out:
# Downloaded ./alz/pet\1.gif
# Downloaded ./alz/pet\2.gif
# Downloaded ./alz/pet\3.gif
# Downloaded ./alz/pet\4.gif
# Downloaded ./alz/pet\5.gif
# Downloaded ./alz/pet\6.gif
# Downloaded ./alz/pet\7.gif
# Downloaded ./alz/pet\8.gif
# Downloaded ./alz/pet\9.gif
# Downloaded ./alz/pet\10.gif
# Downloaded ./alz/pet\11.gif
# Downloaded ./alz/pet\12.gif
# Downloaded ./alz/pet\13.gif
# Downloaded ./alz/pet\14.gif
# Downloaded ./alz/pet\15.gif
# Downloaded ./alz/pet\16.gif
# Downloaded ./alz/pet\17.gif
# Downloaded ./alz/pet\18.gif
# Downloaded ./alz/pet\19.gif

# %%
import os
import requests

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case28/mr1/{numstr}.gif"

for i in range(2,23):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './brchgen/mri'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case28/tc1/{numstr}.gif"

for i in range(2,23):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './brchgen/pet'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)
# Out:
# Downloaded ./brchgen/mri\1.gif
# Downloaded ./brchgen/mri\2.gif
# Downloaded ./brchgen/mri\3.gif
# Downloaded ./brchgen/mri\4.gif
# Downloaded ./brchgen/mri\5.gif
# Downloaded ./brchgen/mri\6.gif
# Downloaded ./brchgen/mri\7.gif
# Downloaded ./brchgen/mri\8.gif
# Downloaded ./brchgen/mri\9.gif
# Downloaded ./brchgen/mri\10.gif
# Downloaded ./brchgen/mri\11.gif
# Downloaded ./brchgen/mri\12.gif
# Downloaded ./brchgen/mri\13.gif
# Downloaded ./brchgen/mri\14.gif
# Downloaded ./brchgen/mri\15.gif
# Downloaded ./brchgen/mri\16.gif
# Downloaded ./brchgen/mri\17.gif
# Downloaded ./brchgen/mri\18.gif
# Downloaded ./brchgen/mri\19.gif
# Downloaded ./brchgen/mri\20.gif
# Downloaded ./brchgen/mri\21.gif
# Downloaded ./brchgen/pet\1.gif
# Downloaded ./brchgen/pet\2.gif
# Downloaded ./brchgen/pet\3.gif
# Downloaded ./brchgen/pet\4.gif
# Downloaded ./brchgen/pet\5.gif
# Downloaded ./brchgen/pet\6.gif
# Downloaded ./brchgen/pet\7.gif
# Downloaded ./brchgen/pet\8.gif
# ...

# %%
import os
import requests

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case36/mr1/{numstr}.gif"

for i in range(9,43):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './nrm/mri'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case36/tc1/{numstr}.gif"

for i in range(9,43):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './nrm/pet'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)
# Out:
# Downloaded ./nrm/mri\1.gif
# Downloaded ./nrm/mri\2.gif
# Downloaded ./nrm/mri\3.gif
# Downloaded ./nrm/mri\4.gif
# Downloaded ./nrm/mri\5.gif
# Downloaded ./nrm/mri\6.gif
# Downloaded ./nrm/mri\7.gif
# Downloaded ./nrm/mri\8.gif
# Downloaded ./nrm/mri\9.gif
# Downloaded ./nrm/mri\10.gif
# Downloaded ./nrm/mri\11.gif
# Downloaded ./nrm/mri\12.gif
# Downloaded ./nrm/mri\13.gif
# Downloaded ./nrm/mri\14.gif
# Downloaded ./nrm/mri\15.gif
# Downloaded ./nrm/mri\16.gif
# Downloaded ./nrm/mri\17.gif
# Downloaded ./nrm/mri\18.gif
# Downloaded ./nrm/mri\19.gif
# Downloaded ./nrm/mri\20.gif
# Downloaded ./nrm/mri\21.gif
# Downloaded ./nrm/mri\22.gif
# Downloaded ./nrm/mri\23.gif
# Downloaded ./nrm/mri\24.gif
# Downloaded ./nrm/mri\25.gif
# Downloaded ./nrm/mri\26.gif
# Downloaded ./nrm/mri\27.gif
# Downloaded ./nrm/mri\28.gif
# Downloaded ./nrm/mri\29.gif
# Downloaded ./nrm/mri\30.gif
# Downloaded ./nrm/mri\31.gif
# Downloaded ./nrm/mri\32.gif
# Downloaded ./nrm/mri\33.gif
# ...

# %%
import os
import requests

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case21/mr1/{numstr}.gif"

for i in range(4,23):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './hyp/mri'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

0# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case21/tc1/{numstr}.gif"

for i in range(4,23):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './hyp/pet'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)
# Out:
# Downloaded ./hyp/mri\1.gif
# Downloaded ./hyp/mri\2.gif
# Downloaded ./hyp/mri\3.gif
# Downloaded ./hyp/mri\4.gif
# Downloaded ./hyp/mri\5.gif
# Downloaded ./hyp/mri\6.gif
# Downloaded ./hyp/mri\7.gif
# Downloaded ./hyp/mri\8.gif
# Downloaded ./hyp/mri\9.gif
# Downloaded ./hyp/mri\10.gif
# Downloaded ./hyp/mri\11.gif
# Downloaded ./hyp/mri\12.gif
# Downloaded ./hyp/mri\13.gif
# Downloaded ./hyp/mri\14.gif
# Downloaded ./hyp/mri\15.gif
# Downloaded ./hyp/mri\16.gif
# Downloaded ./hyp/mri\17.gif
# Downloaded ./hyp/mri\18.gif
# Downloaded ./hyp/mri\19.gif
# Downloaded ./hyp/pet\1.gif
# Downloaded ./hyp/pet\2.gif
# Downloaded ./hyp/pet\3.gif
# Downloaded ./hyp/pet\4.gif
# Downloaded ./hyp/pet\5.gif
# Downloaded ./hyp/pet\6.gif
# Downloaded ./hyp/pet\7.gif
# Downloaded ./hyp/pet\8.gif
# Downloaded ./hyp/pet\9.gif
# Downloaded ./hyp/pet\10.gif
# Downloaded ./hyp/pet\11.gif
# Downloaded ./hyp/pet\12.gif
# Downloaded ./hyp/pet\13.gif
# Downloaded ./hyp/pet\14.gif
# ...

# %%
import os
import requests

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case22/mr1/{numstr}.gif"

for i in range(4,24):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './motor/mri'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

0# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case22/tc1/{numstr}.gif"

for i in range(4,24):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './motor/pet'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)
# Out:
# Downloaded ./motor/mri\1.gif
# Downloaded ./motor/mri\2.gif
# Downloaded ./motor/mri\3.gif
# Downloaded ./motor/mri\4.gif
# Downloaded ./motor/mri\5.gif
# Downloaded ./motor/mri\6.gif
# Downloaded ./motor/mri\7.gif
# Downloaded ./motor/mri\8.gif
# Downloaded ./motor/mri\9.gif
# Downloaded ./motor/mri\10.gif
# Downloaded ./motor/mri\11.gif
# Downloaded ./motor/mri\12.gif
# Downloaded ./motor/mri\13.gif
# Downloaded ./motor/mri\14.gif
# Downloaded ./motor/mri\15.gif
# Downloaded ./motor/mri\16.gif
# Downloaded ./motor/mri\17.gif
# Downloaded ./motor/mri\18.gif
# Downloaded ./motor/mri\19.gif
# Downloaded ./motor/mri\20.gif
# Downloaded ./motor/pet\1.gif
# Downloaded ./motor/pet\2.gif
# Downloaded ./motor/pet\3.gif
# Downloaded ./motor/pet\4.gif
# Downloaded ./motor/pet\5.gif
# Downloaded ./motor/pet\6.gif
# Downloaded ./motor/pet\7.gif
# Downloaded ./motor/pet\8.gif
# Downloaded ./motor/pet\9.gif
# Downloaded ./motor/pet\10.gif
# Downloaded ./motor/pet\11.gif
# ...

# %%
# MRI data
# Categorize data sets, save as 60% train, 20% validation, 20% test
# !pip install opencv-python
# !pip install tensorflow
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split

label_types = ['alz', 'brchgen', 'hyp', 'motor', 'nrm']

for label in label_types:
    cd = os.curdir
    m_path = os.path.join(cd, label, 'mri')
    working_list = os.listdir(m_path)
    ret_list = []
    
   
    for i in range(len(working_list)):
        src = os.path.join(m_path, str(i+1) + '.gif')
        img = load_img(src, color_mode='rgb')
        im = img_to_array(img)
        ret = cv2.resize(im, (256, 256))  
        ret_list.append(ret)
    
    ret_array = np.array(ret_list)
    ret_array = ret_array.astype('float32') / 255.0 # image normalization
    
    # 60% train, 20% validation, 20% test
    X_train, X_temp = train_test_split(ret_array, test_size=0.4, random_state=42)
    X_val, X_test = train_test_split(X_temp, test_size=0.5, random_state=42)

    # transpose arrays to (256, 256, 3, n)
    X_train = np.transpose(X_train, (1, 2, 3, 0))
    X_val = np.transpose(X_val, (1, 2, 3, 0))
    X_test = np.transpose(X_test, (1, 2, 3, 0))


    np.save(f'{label}_mri_train.npy', X_train)
    np.save(f'{label}_mri_val.npy', X_val)
    np.save(f'{label}_mri_test.npy', X_test)
    
    print(f"{label} MRI - Train set shape:", X_train.shape)
    print(f"{label} MRI - Validation set shape:", X_val.shape)
    print(f"{label} MRI - Test set shape:", X_test.shape)
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# alz MRI - Train set shape: (256, 256, 3, 11)
# alz MRI - Validation set shape: (256, 256, 3, 4)
# alz MRI - Test set shape: (256, 256, 3, 4)
# brchgen MRI - Train set shape: (256, 256, 3, 12)
# brchgen MRI - Validation set shape: (256, 256, 3, 4)
# brchgen MRI - Test set shape: (256, 256, 3, 5)
# hyp MRI - Train set shape: (256, 256, 3, 11)
# hyp MRI - Validation set shape: (256, 256, 3, 4)
# hyp MRI - Test set shape: (256, 256, 3, 4)
# motor MRI - Train set shape: (256, 256, 3, 12)
# motor MRI - Validation set shape: (256, 256, 3, 4)
# motor MRI - Test set shape: (256, 256, 3, 4)
# nrm MRI - Train set shape: (256, 256, 3, 20)
# nrm MRI - Validation set shape: (256, 256, 3, 7)
# nrm MRI - Test set shape: (256, 256, 3, 7)

# %%
# PET Data
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split

label_types = ['alz', 'brchgen', 'hyp', 'motor', 'nrm']

for label in label_types:
    cd = os.curdir
    m_path = os.path.join(cd, label, 'pet')
    working_list = os.listdir(m_path)
    ret_list = []
    
    for i in range(len(working_list)):
        src = os.path.join(m_path, str(i+1) + '.gif')
        img = load_img(src, color_mode='rgb')
        im = img_to_array(img)
        ret = cv2.resize(im, (256, 256))  
        ret_list.append(ret)
    
    ret_array = np.array(ret_list)
    ret_array = ret_array.astype('float32') / 255.0 
    
  
    X_train, X_temp = train_test_split(ret_array, test_size=0.4, random_state=42)
    X_val, X_test = train_test_split(X_temp, test_size=0.5, random_state=42)

    X_train = np.transpose(X_train, (1, 2, 3, 0))
    X_val = np.transpose(X_val, (1, 2, 3, 0))
    X_test = np.transpose(X_test, (1, 2, 3, 0))


    np.save(f'{label}_pet_train.npy', X_train)
    np.save(f'{label}_pet_val.npy', X_val)
    np.save(f'{label}_pet_test.npy', X_test)
    
    print(f"{label} PET - Train set shape:", X_train.shape)
    print(f"{label} PET - Validation set shape:", X_val.shape)
    print(f"{label} PET - Test set shape:", X_test.shape)
# Out:
# alz PET - Train set shape: (256, 256, 3, 11)
# alz PET - Validation set shape: (256, 256, 3, 4)
# alz PET - Test set shape: (256, 256, 3, 4)
# brchgen PET - Train set shape: (256, 256, 3, 12)
# brchgen PET - Validation set shape: (256, 256, 3, 4)
# brchgen PET - Test set shape: (256, 256, 3, 5)
# hyp PET - Train set shape: (256, 256, 3, 11)
# hyp PET - Validation set shape: (256, 256, 3, 4)
# hyp PET - Test set shape: (256, 256, 3, 4)
# motor PET - Train set shape: (256, 256, 3, 12)
# motor PET - Validation set shape: (256, 256, 3, 4)
# motor PET - Test set shape: (256, 256, 3, 4)
# nrm PET - Train set shape: (256, 256, 3, 20)
# nrm PET - Validation set shape: (256, 256, 3, 7)
# nrm PET - Test set shape: (256, 256, 3, 7)

# %%
# save all mri
# !pip install opencv-python
# !pip install tensorflow
# import cv2 
# import numpy as np
# from tensorflow.keras.preprocessing.image import img_to_array, load_img

# label_types = ['alz','brchgen','hyp','motor','nrm']
# for label in label_types:
#     cd = os.curdir
#     m_path = os.path.join(cd,label,'mri')
#     working_list = os.listdir(m_path)
#     ret_list = []
#     for i in range(len(working_list)):
#         src = os.path.join(m_path,str(i+1)+'.gif')
#         img = load_img(src, color_mode='rgb')
#         im = img_to_array(img)
#         ret = cv2.resize(im,(256,256))
#         ret_list.append(ret)
#     ret_array = np.stack(ret_list,axis=-1)
#     print(np.shape(ret_array))
#     np.save(label+' '+'mri',ret_array)

# %%
# save all pet

# import cv2 
# import numpy as np
# from tensorflow.keras.preprocessing.image import img_to_array, load_img

# label_types = ['alz','brchgen','hyp','motor','nrm']
# for label in label_types:
#     cd = os.curdir
#     m_path = os.path.join(cd,label,'pet')
#     working_list = os.listdir(m_path)
#     ret_list = []
#     for i in range(len(working_list)):
#         src = os.path.join(m_path,str(i+1)+'.gif')
#         img = load_img(src, color_mode='rgb')
#         im = img_to_array(img)
#         ret = cv2.resize(im,(256,256))
#         ret_list.append(ret)
#     ret_array = np.stack(ret_list,axis=-1)
#     print(np.shape(ret_array))
#     np.save(label+' '+'pet',ret_array)

# %%
from tensorflow.keras.preprocessing.image import array_to_img
m_array = np.load("nrm_mri_test.npy")
array_to_img(m_array[:,:,:,0])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
from tensorflow.keras.preprocessing.image import array_to_img
m_array = np.load("nrm_pet_test.npy")
array_to_img(m_array[:,:,:,0])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
import os
import requests

# List of image URLs
image_urls = []

def get_url(number):
    numstr = str(number).zfill(3)
    return f"https://www.med.harvard.edu/AANLIB/cases/case29/mr1-tc1/{numstr}.gif"

for i in range(5,24):
    image_urls.append(get_url(i))

# Directory to save images
save_dir = './alz/gt'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
# Function to download a single GIF
def download_gif(url, save_path):
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Downloaded {save_path}")
        else:
            print(f"Failed to download {url} - Status Code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading {url}: {e}")

# Batch download GIFs
for idx, url in enumerate(image_urls):
    gif_name = f"{idx + 1}.gif"
    save_path = os.path.join(save_dir, gif_name)
    download_gif(url, save_path)
# Out:
# Downloaded ./alz/gt\1.gif
# Downloaded ./alz/gt\2.gif
# Downloaded ./alz/gt\3.gif
# Downloaded ./alz/gt\4.gif
# Downloaded ./alz/gt\5.gif
# Downloaded ./alz/gt\6.gif
# Downloaded ./alz/gt\7.gif
# Downloaded ./alz/gt\8.gif
# Downloaded ./alz/gt\9.gif
# Downloaded ./alz/gt\10.gif
# Downloaded ./alz/gt\11.gif
# Downloaded ./alz/gt\12.gif
# Downloaded ./alz/gt\13.gif
# Downloaded ./alz/gt\14.gif
# Downloaded ./alz/gt\15.gif
# Downloaded ./alz/gt\16.gif
# Downloaded ./alz/gt\17.gif
# Downloaded ./alz/gt\18.gif
# Downloaded ./alz/gt\19.gif

# %%
# PET Data
ret_list = []
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split
from keras.callbacks import LearningRateScheduler



for i in range(19):
    src = os.path.join('./alz/gt/', str(i+1) + '.gif')
    img = load_img(src, color_mode='rgb')
    im = img_to_array(img)
    ret = cv2.resize(im, (256, 256))  
    ret_list.append(ret)

ret_array = np.array(ret_list)
ret_array = ret_array.astype('float32') / 255.0 


X_train, X_temp = train_test_split(ret_array, test_size=0.4, random_state=42)
X_val, X_test = train_test_split(X_temp, test_size=0.5, random_state=42)

X_train = np.transpose(X_train, (1, 2, 3, 0))
X_val = np.transpose(X_val, (1, 2, 3, 0))
X_test = np.transpose(X_test, (1, 2, 3, 0))


np.save(f'alz_gt_train.npy', X_train)
np.save(f'alz_gt_val.npy', X_val)
np.save(f'alz_gt_test.npy', X_test)
